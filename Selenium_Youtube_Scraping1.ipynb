# %%
from flask import Flask, render_template, request
from flask_cors import CORS, cross_origin
import requests
import logging
import pymongo
import csv
logging.basicConfig(filename="scraper.log", level = logging.INFO)

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen

# %%
app = Flask(__name__)

# %%
@app.route("/", methods=['GET'])
def homepage():
    return render_template("index.html")

@app.route("/channel", methods = ['POST', 'GET'])
def index():
    if request.method == 'POST':
        try:
            searchstring = request.form['content']
            youtube_url = "https://www.youtube.com/@" + searchstring + "/videos"
            print(youtube_url)
            driver.get(youtube_url)
            content = driver.page_source.encode('utf-8').strip()
            soup = bs(content, 'html.parser')
            titles = soup.find_all('a', id='video-title-link')
            views = soup.find_all('span', class_ = 'inline-metadata-item style-scope ytd-video-meta-block')
            video_urls = soup.find_all('a', id = 'video-title-link')
            i = 0 
            j = 0
            li = []
            for title in titles[:5]:
                raw_dic = {}
                raw_dic['Title']= (title.text)
                raw_dic['Views'] = (views[i].text)
                raw_dic['Time of Posting'] = (views[i+1].text)
                raw_dic['Youtube URL'] = "https://www.youtube.com{}".format(video_urls[j].get('href'))
                print('\n{}\n{}\n{}\nhttps://www.youtube.com{}'.format(title.text, views[i].text, views[i+1].text, video_urls[j].get('href')))
                i+=2
                j+=1
                li.append(raw_dic)
            fields = ['Title', 'Views', 'Time of Posting', 'Youtube URL']
            print(li)
            filename = searchstring + "_scraped.csv"
            with open(filename,'w', encoding="utf-8") as csvfile:
                writer = csv.DictWriter(csvfile, fieldnames=fields)
                writer.writeheader()
                searchstring = request.form['content']
                youtube_url = "https://www.youtube.com/@" + searchstring + "/videos"
                print(youtube_url)
                driver.get(youtube_url)
                content = driver.page_source.encode('utf-8').strip()
                soup = bs(content, 'html.parser')
                titles = soup.find_all('a', id='video-title-link')
                views = soup.find_all('span', class_ = 'inline-metadata-item style-scope ytd-video-meta-block')
                video_urls = soup.find_all('a', id = 'video-title-link')
                i = 0 
                j = 0
                li = []
                for title in titles[:5]:
                    raw_dic = {}
                    raw_dic['Title']= (title.text)
                    raw_dic['Views'] = (views[i].text)
                    raw_dic['Time of Posting'] = (views[i+1].text)
                    raw_dic['Youtube URL'] = "https://www.youtube.com{}".format(video_urls[j].get('href'))
                    print('\n{}\n{}\n{}\nhttps://www.youtube.com{}'.format(title.text, views[i].text, views[i+1].text, video_urls[j].get('href')))
                    i+=2
                    j+=1
                    li.append(raw_dic)
                fields = ['Title', 'Views', 'Time of Posting', 'Youtube URL']
                print(li)
                filename = searchstring + "_scraped.csv"
                with open(filename,'w', encoding="utf-8") as csvfile:
                    writer = csv.DictWriter(csvfile, fieldnames=fields)
                    writer.writeheader()
                    writer.writerows(li)
                    
                return render_template('result.html', list_scrape = li[0:(len(li))])
        except Exception as e:
            logging.info(e)
            return "Something Wrong"
    else:
        return render_template("index.html")
        
        
if __name__ == "__main__":
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# https://www.youtube.com/@BhangraEmpire/videos
#
# JEE NI LAGDA WORKSHOP | KARAN AUJLA | BHANGRA EMPIRE
# 19K views
# 2 weeks ago
# https://www.youtube.com/watch?v=CbYhTtjsQ_o
#
# 9:45 BHANGRA WORKSHOP | PRABH | BHANGRA EMPIRE
# 26K views
# 3 weeks ago
# https://www.youtube.com/watch?v=kI7Hw7Nse1o
#
# MODERN MIRZA BHANGRA WORKSHOP | RAF SAPERRA | BHANGRA EMPIRE
# 15K views
# 1 month ago
# https://www.youtube.com/watch?v=1zl2do33mDM
#
# Bhangra Empire - Jashan and Anureet's Wedding Dance
# 17K views
# 1 month ago
# https://www.youtube.com/watch?v=SAO3zp6K7Ic
#
# TAKE IT EASY BHANGRA WORKSHOP | KARAN AUJLA | BHANGRA EMPIRE
# 24K views
# 1 month ago
# https://www.youtube.com/watch?v=GmpUoHIxDIc
# [{'Title': 'JEE NI LAGDA WORKSHOP | KARAN AUJLA | BHANGRA EMPIRE', 'Views': '19K views', 'Time of Posting': '2 weeks ago', 'Youtube URL': 'https://www.youtube.com/watch?v=CbYhTtjsQ_o'}, {'Title': '9:45 BHANGRA WORKSHOP | PRABH | BHANGRA EMPIRE', 'Views': '26K views', 'Time of Posting': '3 weeks ago', 'Youtube URL': 'https://www.youtube.com/watch?v=kI7Hw7Nse1o'}, {'Title': 'MODERN MIRZA BHANGRA WORKSHOP | RAF SAPERRA | BHANGRA EMPIRE', 'Views': '15K views', 'Time of Posting': '1 month ago', 'Youtube URL': 'https://www.youtube.com/watch?v=1zl2do33mDM'}, {'Title': "Bhangra Empire - Jashan and Anureet's Wedding Dance", 'Views': '17K views', 'Time of Posting': '1 month ago', 'Youtube URL': 'https://www.youtube.com/watch?v=SAO3zp6K7Ic'}, {'Title': 'TAKE IT EASY BHANGRA WORKSHOP | KARAN AUJLA | BHANGRA EMPIRE', 'Views': '24K views', 'Time of Posting': '1 month ago', 'Youtube URL': 'https://www.youtube.com/watch?v=GmpUoHIxDIc'}]
# https://www.youtube.com/@BhangraEmpire/videos
#
# JEE NI LAGDA WORKSHOP | KARAN AUJLA | BHANGRA EMPIRE
# 19K views
# 2 weeks ago
# https://www.youtube.com/watch?v=CbYhTtjsQ_o
#
# 9:45 BHANGRA WORKSHOP | PRABH | BHANGRA EMPIRE
# 26K views
# 3 weeks ago
# https://www.youtube.com/watch?v=kI7Hw7Nse1o
#
# MODERN MIRZA BHANGRA WORKSHOP | RAF SAPERRA | BHANGRA EMPIRE
# 15K views
# 1 month ago
# https://www.youtube.com/watch?v=1zl2do33mDM
#
# Bhangra Empire - Jashan and Anureet's Wedding Dance
# 17K views
# 1 month ago
# https://www.youtube.com/watch?v=SAO3zp6K7Ic
#
# TAKE IT EASY BHANGRA WORKSHOP | KARAN AUJLA | BHANGRA EMPIRE
# 24K views
# 1 month ago
# https://www.youtube.com/watch?v=GmpUoHIxDIc
# [{'Title': 'JEE NI LAGDA WORKSHOP | KARAN AUJLA | BHANGRA EMPIRE', 'Views': '19K views', 'Time of Posting': '2 weeks ago', 'Youtube URL': 'https://www.youtube.com/watch?v=CbYhTtjsQ_o'}, {'Title': '9:45 BHANGRA WORKSHOP | PRABH | BHANGRA EMPIRE', 'Views': '26K views', 'Time of Posting': '3 weeks ago', 'Youtube URL': 'https://www.youtube.com/watch?v=kI7Hw7Nse1o'}, {'Title': 'MODERN MIRZA BHANGRA WORKSHOP | RAF SAPERRA | BHANGRA EMPIRE', 'Views': '15K views', 'Time of Posting': '1 month ago', 'Youtube URL': 'https://www.youtube.com/watch?v=1zl2do33mDM'}, {'Title': "Bhangra Empire - Jashan and Anureet's Wedding Dance", 'Views': '17K views', 'Time of Posting': '1 month ago', 'Youtube URL': 'https://www.youtube.com/watch?v=SAO3zp6K7Ic'}, {'Title': 'TAKE IT EASY BHANGRA WORKSHOP | KARAN AUJLA | BHANGRA EMPIRE', 'Views': '24K views', 'Time of Posting': '1 month ago', 'Youtube URL': 'https://www.youtube.com/watch?v=GmpUoHIxDIc'}]
# https://www.youtube.com/@PW-Foundation/videos
#
# 5 Months MASTERPLAN for Class 10th Board !! 🎯 🔥
# 6K views
# 32 minutes ago
# https://www.youtube.com/watch?v=a2n9xcfXGpY
#
# Chemical Reactions and Equations in 55 in mins || Class - 10th Boards
# 12K views
# 19 hours ago
# https://www.youtube.com/watch?v=S4nFKzoSCWs
#
# POWER SHARING in 40 mins || Class - 10th Boards
# 8.5K views
# 1 day ago
# https://www.youtube.com/watch?v=pecNtI_QXEI
#
# DEVELOPMENT in 45 mins || Class - 10th Boards
# 6.4K views
# 2 days ago
# https://www.youtube.com/watch?v=PXcgTSs-_p8
#
# REAL NUMBERS in 60 mins || Class - 10th Boards
# 9.8K views
# 3 days ago
# https://www.youtube.com/watch?v=JGJv4jlf8aQ
# [{'Title': '5 Months MASTERPLAN for Class 10th Board !! 🎯 🔥', 'Views': '6K views', 'Time of Posting': '32 minutes ago', 'Youtube URL': 'https://www.youtube.com/watch?v=a2n9xcfXGpY'}, {'Title': 'Chemical Reactions and Equations in 55 in mins || Class - 10th Boards', 'Views': '12K views', 'Time of Posting': '19 hours ago', 'Youtube URL': 'https://www.youtube.com/watch?v=S4nFKzoSCWs'}, {'Title': 'POWER SHARING in 40 mins || Class - 10th Boards', 'Views': '8.5K views', 'Time of Posting': '1 day ago', 'Youtube URL': 'https://www.youtube.com/watch?v=pecNtI_QXEI'}, {'Title': 'DEVELOPMENT in 45 mins || Class - 10th Boards', 'Views': '6.4K views', 'Time of Posting': '2 days ago', 'Youtube URL': 'https://www.youtube.com/watch?v=PXcgTSs-_p8'}, {'Title': 'REAL NUMBERS in 60 mins || Class - 10th Boards', 'Views': '9.8K views', 'Time of Posting': '3 days ago', 'Youtube URL': 'https://www.youtube.com/watch?v=JGJv4jlf8aQ'}]
# https://www.youtube.com/@PW-Foundation/videos
#
# 5 Months MASTERPLAN for Class 10th Board !! 🎯 🔥
# 6K views
# 32 minutes ago
# https://www.youtube.com/watch?v=a2n9xcfXGpY
#
# Chemical Reactions and Equations in 55 in mins || Class - 10th Boards
# 12K views
# 19 hours ago
# https://www.youtube.com/watch?v=S4nFKzoSCWs
#
# POWER SHARING in 40 mins || Class - 10th Boards
# 8.5K views
# 1 day ago
# https://www.youtube.com/watch?v=pecNtI_QXEI
#
# DEVELOPMENT in 45 mins || Class - 10th Boards
# 6.4K views
# 2 days ago
# https://www.youtube.com/watch?v=PXcgTSs-_p8
#
# REAL NUMBERS in 60 mins || Class - 10th Boards
# 9.8K views
# 3 days ago
# https://www.youtube.com/watch?v=JGJv4jlf8aQ
# [{'Title': '5 Months MASTERPLAN for Class 10th Board !! 🎯 🔥', 'Views': '6K views', 'Time of Posting': '32 minutes ago', 'Youtube URL': 'https://www.youtube.com/watch?v=a2n9xcfXGpY'}, {'Title': 'Chemical Reactions and Equations in 55 in mins || Class - 10th Boards', 'Views': '12K views', 'Time of Posting': '19 hours ago', 'Youtube URL': 'https://www.youtube.com/watch?v=S4nFKzoSCWs'}, {'Title': 'POWER SHARING in 40 mins || Class - 10th Boards', 'Views': '8.5K views', 'Time of Posting': '1 day ago', 'Youtube URL': 'https://www.youtube.com/watch?v=pecNtI_QXEI'}, {'Title': 'DEVELOPMENT in 45 mins || Class - 10th Boards', 'Views': '6.4K views', 'Time of Posting': '2 days ago', 'Youtube URL': 'https://www.youtube.com/watch?v=PXcgTSs-_p8'}, {'Title': 'REAL NUMBERS in 60 mins || Class - 10th Boards', 'Views': '9.8K views', 'Time of Posting': '3 days ago', 'Youtube URL': 'https://www.youtube.com/watch?v=JGJv4jlf8aQ'}]
